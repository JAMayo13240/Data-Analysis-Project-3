# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
#Median List Price: The median price at which homes across various geographies were listed.

first_read = pd.read_csv('Metro_mlp_uc_sfr_sm_month.csv')
first_read.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0    102001         0    United States    country       NaN    262433.0
# 1    394913         1     New York, NY        msa        NY    492633.0
# 2    753899         2  Los Angeles, CA        msa        CA    778333.0
# 3    394463         3      Chicago, IL        msa        IL    295800.0
# 4    394514         4       Dallas, TX        msa        TX    325253.0
#
#    2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2023-03-31  \
# 0    270467.0    277133.0    280500.0    280800.0  ...    374000.0
# 1    499333.0    507966.0    516633.0    522967.0  ...    634633.0
# 2    791667.0    799667.0    806300.0    805967.0  ...    929966.0
# 3    309133.0    317600.0    321567.0    319933.0  ...    309967.0
# 4    330319.0    333613.0    333632.0    330298.0  ...    404630.0
#
#    2023-04-30  2023-05-31  2023-06-30  2023-07-31  2023-08-31  2023-09-30  \
# ...

# %%
first_read.tail()
# Out:
#      RegionID  SizeRank     RegionName RegionType StateName  2018-03-31  \
# 922    753929       935     Zapata, TX        msa        TX         NaN
# 923    394743       936  Ketchikan, AK        msa        AK    324500.0
# 924    753874       937      Craig, CO        msa        CO    193817.0
# 925    395188       938     Vernon, TX        msa        TX         NaN
# 926    394767       939     Lamesa, TX        msa        TX     96800.0
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2023-03-31  \
# 922         NaN         NaN         NaN         NaN  ...    146833.0
# 923    327833.0    333000.0    344500.0    358167.0  ...    438500.0
# 924    196400.0    197050.0    197800.0    195933.0  ...    355817.0
# 925         NaN         NaN         NaN         NaN  ...     94241.0
# 926    103467.0    108450.0    114650.0    119567.0  ...    161000.0
#
#      2023-04-30  2023-05-31  2023-06-30  2023-07-31  2023-08-31  2023-09-30  \
# ...

# %%
df_california = first_read[first_read['StateName']== 'CA']
print(df_california)
# Out:
#      RegionID  SizeRank           RegionName RegionType StateName  2018-03-31  \
# 2      753899         2      Los Angeles, CA        msa        CA    778333.0
# 12     395057        12    San Francisco, CA        msa        CA    895731.0
# 13     395025        13        Riverside, CA        msa        CA    389967.0
# 17     395056        17        San Diego, CA        msa        CA    702667.0
# 26     395045        26       Sacramento, CA        msa        CA    442633.0
# 35     395059        36         San Jose, CA        msa        CA   1199456.0
# 56     394619        57           Fresno, CA        msa        CA    296167.0
# 62     394357        63      Bakersfield, CA        msa        CA    256633.0
# 70     394952        71           Oxnard, CA        msa        CA    751450.0
# 76     395134        77         Stockton, CA        msa        CA    378000.0
# 102    394871       103          Modesto, CA        msa        CA    342613.0
# ...

# %%
df_texas = first_read[first_read['StateName']== 'TX']
print(df_texas)
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 4      394514         4       Dallas, TX        msa        TX    325253.0
# 5      394692         5      Houston, TX        msa        TX    294633.0
# 24     395055        24  San Antonio, TX        msa        TX    260967.0
# 29     394355        29       Austin, TX        msa        TX    363492.0
# 66     394843        67      McAllen, TX        msa        TX    185833.0
# ..        ...       ...              ...        ...       ...         ...
# 920    395142       933   Sweetwater, TX        msa        TX    124471.0
# 921    394968       934        Pecos, TX        msa        TX         NaN
# 922    753929       935       Zapata, TX        msa        TX         NaN
# 925    395188       938       Vernon, TX        msa        TX         NaN
# 926    394767       939       Lamesa, TX        msa        TX     96800.0
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2023-03-31  \
# ...

# %%
df_florida = first_read[first_read['StateName']== 'FL']
print(df_florida)
# Out:
#      RegionID  SizeRank             RegionName RegionType StateName  \
# 8      394856         8              Miami, FL        msa        FL
# 18     395148        18              Tampa, FL        msa        FL
# 22     394943        22            Orlando, FL        msa        FL
# 39     394714        40       Jacksonville, FL        msa        FL
# 72     753906        73         North Port, FL        msa        FL
# 77     394440        78         Cape Coral, FL        msa        FL
# 81     394766        82           Lakeland, FL        msa        FL
# 89     394528        90            Deltona, FL        msa        FL
# 96     394957        97           Palm Bay, FL        msa        FL
# 110    394971       111          Pensacola, FL        msa        FL
# 114    394995       115     Port St. Lucie, FL        msa        FL
# 144    395146       145        Tallahassee, FL        msa        FL
# 146    394901       147             Naples, FL        msa        FL
# ...

# %%
df_newyork = first_read[first_read['StateName']== 'NY']
print(df_newyork)
# Out:
#      RegionID  SizeRank        RegionName RegionType StateName  2018-03-31  \
# 1      394913         1      New York, NY        msa        NY    492633.0
# 49     394425        50       Buffalo, NY        msa        NY    164967.0
# 51     395031        52     Rochester, NY        msa        NY    164567.0
# 63     394308        64        Albany, NY        msa        NY    214267.0
# 85     845159        86  Poughkeepsie, NY        msa        NY         NaN
# 90     395143        91      Syracuse, NY        msa        NY    147100.0
# 167    395179       169         Utica, NY        msa        NY    130783.0
# 193    394387       195    Binghamton, NY        msa        NY    120083.0
# 237    394748       241      Kingston, NY        msa        NY    266200.0
# 324    394719       328     Jamestown, NY        msa        NY    117308.0
# 327    394633       331   Glens Falls, NY        msa        NY    222950.0
# ...

# %%
df_pennsylvania = first_read[first_read['StateName']== 'PA']
print(df_pennsylvania)
# Out:
#      RegionID  SizeRank            RegionName RegionType StateName  \
# 7      394974         7      Philadelphia, PA        msa        PA
# 27     394982        27        Pittsburgh, PA        msa        PA
# 69     394318        70         Allentown, PA        msa        PA
# 98     394666        99        Harrisburg, PA        msa        PA
# 100    395075       101          Scranton, PA        msa        PA
# 103    394768       104         Lancaster, PA        msa        PA
# 121    395244       122              York, PA        msa        PA
# 127    395015       128           Reading, PA        msa        PA
# 182    394572       184              Erie, PA        msa        PA
# 259    394553       263  East Stroudsburg, PA        msa        PA
# 269    395125       273     State College, PA        msa        PA
# 273    394453       277      Chambersburg, PA        msa        PA
# 300    395000       304        Pottsville, PA        msa        PA
# ...

# %%
df = pd.read_csv('Metro_mlp_uc_sfr_sm_month.csv')

# %%
selected_columns = ['StateName'] + [col for col in df.columns if any(year in col for year in ['2018', '2019', '2020', '2021', '2022', '2023'])]
selected_data = df[selected_columns]
selected_data
# Out:
#     StateName  2018-03-31  2018-04-30  2018-05-31  2018-06-30  2018-07-31  \
# 0         NaN    262433.0    270467.0    277133.0    280500.0    280800.0
# 1          NY    492633.0    499333.0    507966.0    516633.0    522967.0
# 2          CA    778333.0    791667.0    799667.0    806300.0    805967.0
# 3          IL    295800.0    309133.0    317600.0    321567.0    319933.0
# 4          TX    325253.0    330319.0    333613.0    333632.0    330298.0
# ..        ...         ...         ...         ...         ...         ...
# 922        TX         NaN         NaN         NaN         NaN         NaN
# 923        AK    324500.0    327833.0    333000.0    344500.0    358167.0
# 924        CO    193817.0    196400.0    197050.0    197800.0    195933.0
# 925        TX         NaN         NaN         NaN         NaN         NaN
# 926        TX     96800.0    103467.0    108450.0    114650.0    119567.0
#
#      2018-08-31  2018-09-30  2018-10-31  2018-11-30  ...  2023-03-31  \
# ...

# %%
# Filter the data for proper states
# stuff=[0,50000,100000,150000,200000,250000,300000,350000,400000,450000]
selected_data_ny_tx = selected_data[selected_data['StateName'].isin(['CA', 'FL', 'NY', 'PA', 'TX'])]
# Create a new column for each year and add the values for each
for year in range(2018, 2024):
    selected_data_ny_tx[f'Total_{year}'] = selected_data_ny_tx.apply(lambda row: row.filter(like=str(year)).sum(), axis=1)
    
# Group by state and select the total for each year
grouped_df = selected_data_ny_tx.groupby('StateName')[[f'Total_{year}' for year in range(2018, 2024)]].sum()

# Plot the bar chart
ax = grouped_df.plot(kind='bar', figsize=(14, 8))
ax.set_ylabel('List Price')
ax.set_xlabel('State')
ax.set_title('List Price by State (2018 to 2023)')
# ax.set_ylabel(stuff)
# Save the chart as an image (PNG format in this example)
plt.savefig('bar_chart.png')
plt.show()

# %%
#filter data to year 
# Define the range for the year 2018
start_date = pd.Timestamp('2018-01-01')
end_date = pd.Timestamp('2018-12-31')

# Use list comprehension to filter columns within the range of the year 2018
filtered_columns = list(df_pennsylvania.columns[:5]) + [column for column in first_read.columns if start_date <= pd.to_datetime(column, errors='coerce') <= end_date]

# Create a new DataFrame using the filtered columns
df_2018 = df_pennsylvania[filtered_columns]

df_2018['avg_of_2018'] = (df_2018['2018-03-31'] + df_2018['2018-04-30'] + df_2018['2018-05-31'] + df_2018['2018-06-30'] + df_2018['2018-07-31'] + df_2018['2018-04-30'] + df_2018['2018-08-31'] + df_2018['2018-09-30'] + df_2018['2018-10-31'] + df_2018['2018-11-30'] + df_2018['2018-12-31']) / 11

# Display the new DataFrame
df_2018.head()
# Out:
#      RegionID  SizeRank        RegionName RegionType StateName  2018-03-31  \
# 7      394974         7  Philadelphia, PA        msa        PA    226600.0
# 27     394982        27    Pittsburgh, PA        msa        PA    161600.0
# 69     394318        70     Allentown, PA        msa        PA    202933.0
# 98     394666        99    Harrisburg, PA        msa        PA    174150.0
# 100    395075       101      Scranton, PA        msa        PA    133233.0
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  2018-08-31  2018-09-30  \
# 7      235800.0    245800.0    254133.0    257967.0    256300.0    253000.0
# 27     166300.0    171333.0    174633.0    173267.0    171567.0    169833.0
# 69     209600.0    217800.0    222833.0    224800.0    223267.0    221433.0
# 98     178583.0    184267.0    187700.0    188933.0    188900.0    188600.0
# 100    137267.0    143933.0    147300.0    151633.0    152333.0    152300.0
#
#      2018-10-31  2018-11-30  2018-12-31    avg_of_2018
# ...

# %%
df_2018.plot()
plt.show()

# %%
first_read.columns
new_df = first_read[[]]

# %%
# Specify the specific years and StateNames you are interested in
selected_years = [2018, 2019, 2020, 2021, 2022, 2023]  
selected_states = ['CA', 'NY', 'TX', 'FL', 'PA']  

# Filter DataFrame for selected years and StateNames
filtered_df = first_read[(first_read['Year'].dt.year.isin(selected_years)) & (df['StateName'].isin(selected_states))]

# Plot the results
plt.figure(figsize=(12, 6))

for state in selected_states:
    state_data = filtered_df[filtered_df['StateName'] == state]
    plt.plot(state_data['Year'], state_data['ListPrice'], label=state, marker='o')

plt.title('List Prices for Specific StateNames and Years')
plt.xlabel('Year')
plt.ylabel('List Price')
plt.legend(title='StateName', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mindy\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\mindy\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\mindy\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Filter by the array of states and years
selected_states = ['California', 'New York', 'Texas', 'Florida', 'Pennsylvania']
selected_years = [2018, 2019, 2020, 2021, 2022, 2023]

filtered_df = df[df['StateName'].isin(selected_states)]
filtered_df = filtered_df[filtered_df.columns[filtered_df.columns.year.isin(selected_years)]]

# Calculate the average median list price for each state
average_prices = filtered_df.groupby('StateName').median().mean(axis=1) / 1000  # in thousands

# Plot the bar chart
plt.bar(average_prices.index, average_prices)
plt.title('Average Median List Price by State')
plt.xlabel('StateName')
plt.ylabel('Average Median List Price (in thousands)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 6
#       3 selected_years = [2018, 2019, 2020, 2021, 2022, 2023]
#       5 filtered_df = df[df['StateName'].isin(selected_states)]
# ----> 6 filtered_df = filtered_df[filtered_df.columns[filtered_df.columns.year.isin(selected_years)]]
#       8 # Calculate the average median list price for each state
#       9 average_prices = filtered_df.groupby('StateName').median().mean(axis=1) / 1000  # in thousands
#
# AttributeError: 'Index' object has no attribute 'year'
