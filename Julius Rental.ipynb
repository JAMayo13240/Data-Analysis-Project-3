# %%
import pandas as pd
import numpy as np

# %%
rental_df = pd.read_csv('Metro_zori_uc_sfrcondomfr_sm_month.csv')
rental_df.head(10)

# Zillow Observed Rent Index (ZORI)
# Out:
#    RegionID  SizeRank        RegionName RegionType StateName   2015-01-31  \
# 0    102001         0     United States    country       NaN  1228.784000
# 1    394913         1      New York, NY        msa        NY  2286.942293
# 2    753899         2   Los Angeles, CA        msa        CA  1822.376921
# 3    394463         3       Chicago, IL        msa        IL  1385.601820
# 4    394514         4        Dallas, TX        msa        TX  1114.978459
# 5    394692         5       Houston, TX        msa        TX  1239.202535
# 6    395209         6    Washington, DC        msa        VA  1717.578935
# 7    394974         7  Philadelphia, PA        msa        PA  1253.795732
# 8    394856         8         Miami, FL        msa        FL  1494.054348
# 9    394347         9       Atlanta, GA        msa        GA  1056.278664
#
#     2015-02-28   2015-03-31   2015-04-30   2015-05-31  ...   2023-03-31  \
# 0  1235.398148  1244.250266  1254.031553  1263.701003  ...  1913.956669
# ...

# %%
state_rentals_df = rental_df.loc[rental_df["RegionName"].isin(["TX", "CA", "FL", "PA", "NY"])]
state_rentals_df
# Out:
# Empty DataFrame
# ...
