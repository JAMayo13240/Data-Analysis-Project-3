# %%
import pandas as pd
import plotly as plt
import plotly.graph_objects as go
import numpy as np

# %%
sale_df =pd.read_csv('Metro_invt_fs_uc_sfr_sm_month.csv')
sale_df.head(10)
# For sale listings per month
# Out:
#    RegionID  SizeRank        RegionName RegionType StateName  2018-03-31  \
# 0    102001         0     United States    country       NaN   1256841.0
# 1    394913         1      New York, NY        msa        NY     52726.0
# 2    753899         2   Los Angeles, CA        msa        CA     17825.0
# 3    394463         3       Chicago, IL        msa        IL     29930.0
# 4    394514         4        Dallas, TX        msa        TX     22961.0
# 5    394692         5       Houston, TX        msa        TX     24829.0
# 6    395209         6    Washington, DC        msa        VA     17731.0
# 7    394974         7  Philadelphia, PA        msa        PA     23376.0
# 8    394856         8         Miami, FL        msa        FL     27420.0
# 9    394347         9       Atlanta, GA        msa        GA     22927.0
#
#    2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2023-03-31  \
# 0   1326695.0   1412965.0   1479262.0   1527468.0  ...    734588.0
# 1     57399.0     62374.0     66396.0     68302.0  ...     24646.0
# 2     19309.0     20822.0     22059.0     23397.0  ...     13155.0
# 3     32526.0     35219.0     36854.0     38278.0  ...     19674.0
# 4     24748.0     27040.0     29241.0     31113.0  ...     16320.0
# 5     26543.0     28791.0     30278.0     31523.0  ...     19336.0
# 6     20762.0     23443.0     23423.0     21792.0  ...      9306.0
# 7     25246.0     26932.0     27697.0     27182.0  ...     11437.0
# 8     27592.0     27531.0     27005.0     26568.0  ...     17135.0
# 9     24071.0     25436.0     26472.0     27513.0  ...     17124.0
#
#    2023-04-30  2023-05-31  2023-06-30  2023-07-31  2023-08-31  2023-09-30  \
# 0    742155.0    774262.0    801169.0    825009.0    844710.0    853587.0
# 1     24955.0     25893.0     26405.0     26465.0     26021.0     25255.0
# 2     13074.0     13363.0     13508.0     13558.0     13635.0     13665.0
# 3     20028.0     21008.0     21656.0     21896.0     22070.0     22066.0
# 4     17220.0     19181.0     20894.0     21860.0     22333.0     22390.0
# 5     19660.0     20342.0     20855.0     21636.0     22190.0     22213.0
# 6      9868.0     10736.0     10903.0     10624.0     10264.0      9947.0
# 7     11737.0     12282.0     12461.0     12441.0     12408.0     12418.0
# 8     16335.0     15696.0     15072.0     14832.0     14768.0     14865.0
# 9     16808.0     17113.0     17459.0     18033.0     18444.0     18693.0
#
#    2023-10-31  2023-11-30  2023-12-31
# 0    868725.0    859587.0    821812.0
# 1     25182.0     24498.0     22783.0
# 2     14054.0     13865.0     12983.0
# 3     22496.0     21952.0     20302.0
# 4     22477.0     22261.0     21506.0
# 5     22026.0     21672.0     20961.0
# 6      9812.0      9304.0      8244.0
# 7     12699.0     12515.0     11653.0
# 8     15445.0     16068.0     16582.0
# 9     19022.0     19072.0     18473.0
#
# [10 rows x 75 columns]

# %%
sale_df['RegionName'].unique()
# Out:
# array(['United States', 'New York, NY', 'Los Angeles, CA', 'Chicago, IL',
#        'Dallas, TX', 'Houston, TX', 'Washington, DC', 'Philadelphia, PA',
#        'Miami, FL', 'Atlanta, GA', 'Boston, MA', 'Phoenix, AZ',
#        'San Francisco, CA', 'Riverside, CA', 'Detroit, MI', 'Seattle, WA',
#        'Minneapolis, MN', 'San Diego, CA', 'Tampa, FL', 'Denver, CO',
#        'Baltimore, MD', 'St. Louis, MO', 'Orlando, FL', 'Charlotte, NC',
#        'San Antonio, TX', 'Portland, OR', 'Sacramento, CA',
#        'Pittsburgh, PA', 'Cincinnati, OH', 'Austin, TX', 'Las Vegas, NV',
#        'Kansas City, MO', 'Columbus, OH', 'Indianapolis, IN',
#        'Cleveland, OH', 'San Jose, CA', 'Nashville, TN',
#        'Virginia Beach, VA', 'Providence, RI', 'Jacksonville, FL',
#        'Milwaukee, WI', 'Oklahoma City, OK', 'Raleigh, NC', 'Memphis, TN',
#        'Richmond, VA', 'Louisville, KY', 'New Orleans, LA',
#        'Salt Lake City, UT', 'Hartford, CT', 'Buffalo, NY',
#        'Birmingham, AL', 'Rochester, NY', 'Grand Rapids, MI',
#        'Tucson, AZ', 'Urban Honolulu, HI', 'Tulsa, OK', 'Fresno, CA',
#        'Worcester, MA', 'Omaha, NE', 'Bridgeport, CT', 'Greenville, SC',
#        'Albuquerque, NM', 'Bakersfield, CA', 'Albany, NY',
#        'Knoxville, TN', 'Baton Rouge, LA', 'McAllen, TX', 'New Haven, CT',
#        'El Paso, TX', 'Allentown, PA', 'Oxnard, CA', 'Columbia, SC',
#        'North Port, FL', 'Dayton, OH', 'Charleston, SC', 'Greensboro, NC',
#        'Stockton, CA', 'Cape Coral, FL', 'Boise City, ID',
#        'Colorado Springs, CO', 'Little Rock, AR', 'Lakeland, FL',
#        'Akron, OH', 'Des Moines, IA', 'Springfield, MA',
#        'Poughkeepsie, NY', 'Ogden, UT', 'Madison, WI', 'Winston, NC',
#        'Deltona, FL', 'Syracuse, NY', 'Provo, UT', 'Toledo, OH',
#        'Wichita, KS', 'Durham, NC', 'Augusta, GA', 'Palm Bay, FL',
#        'Jackson, MS', 'Harrisburg, PA', 'Spokane, WA', 'Scranton, PA',
#        'Chattanooga, TN', 'Modesto, CA', 'Lancaster, PA', 'Portland, ME',
#        'Youngstown, OH', 'Lansing, MI', 'Fayetteville, AR',
#        'Fayetteville, NC', 'Lexington, KY', 'Pensacola, FL',
#        'Santa Rosa, CA', 'Reno, NV', 'Huntsville, AL',
#        'Port St. Lucie, FL', 'Lafayette, LA', 'Myrtle Beach, SC',
#        'Springfield, MO', 'Visalia, CA', 'Killeen, TX', 'Asheville, NC',
#        'York, PA', 'Vallejo, CA', 'Santa Maria, CA', 'Salinas, CA',
#        'Salem, OR', 'Mobile, AL', 'Reading, PA', 'Corpus Christi, TX',
#        'Brownsville, TX', 'Manchester, NH', 'Fort Wayne, IN',
#        'Gulfport, MS', 'Salisbury, MD', 'Flint, MI', 'Peoria, IL',
#        'Canton, OH', 'Savannah, GA', 'Anchorage, AK', 'Beaumont, TX',
#        'Shreveport, LA', 'Trenton, NJ', 'Montgomery, AL', 'Davenport, IA',
#        'Tallahassee, FL', 'Eugene, OR', 'Naples, FL', 'Ann Arbor, MI',
#        'Ocala, FL', 'Hickory, NC', 'Huntington, WV', 'Fort Collins, CO',
#        'Rockford, IL', 'Lincoln, NE', 'Gainesville, FL', 'Boulder, CO',
#        'Green Bay, WI', 'Columbus, GA', 'South Bend, IN',
#        'Spartanburg, SC', 'Greeley, CO', 'Lubbock, TX', 'Clarksville, TN',
#        'Roanoke, VA', 'Evansville, IN', 'Kingsport, TN', 'Kennewick, WA',
#        'Utica, NY', 'Hagerstown, MD', 'Duluth, MN', 'Olympia, WA',
#        'Longview, TX', 'Wilmington, NC', 'San Luis Obispo, CA',
#        'Crestview, FL', 'Merced, CA', 'Waco, TX', 'Cedar Rapids, IA',
#        'Atlantic City, NJ', 'Bremerton, WA', 'Sioux Falls, SD',
#        'Santa Cruz, CA', 'Erie, PA', 'Norwich, CT', 'Amarillo, TX',
#        'Laredo, TX', 'Tuscaloosa, AL', 'College Station, TX',
#        'Kalamazoo, MI', 'Lynchburg, VA', 'Charleston, WV', 'Yakima, WA',
#        'Fargo, ND', 'Binghamton, NY', 'Fort Smith, AR', 'Appleton, WI',
#        'Prescott Valley, AZ', 'Topeka, KS', 'Macon, GA', 'Tyler, TX',
#        'Barnstable Town, MA', 'Daphne, AL', 'Bellingham, WA',
#        'Burlington, VT', 'Rochester, MN', 'Lafayette, IN',
#        'Champaign, IL', 'Medford, OR', 'Lebanon, NH',
#        'Charlottesville, VA', 'Lake Charles, LA', 'Las Cruces, NM',
#        'Chico, CA', 'Hilton Head Island, SC', 'Athens, GA',
#        'Lake Havasu City, AZ', 'Columbia, MO', 'Springfield, IL',
#        'Houma, LA', 'Monroe, LA', 'Elkhart, IN', 'Johnson City, TN',
#        'Yuma, AZ', 'Gainesville, GA', 'Jacksonville, NC', 'Florence, SC',
#        'Hilo, HI', 'St. Cloud, MN', 'Racine, WI', 'Bend, OR',
#        'Saginaw, MI', 'Warner Robins, GA', 'Terre Haute, IN',
#        'Torrington, CT', 'Punta Gorda, FL', 'Billings, MT', 'Redding, CA',
#        'Kingston, NY', 'Panama City, FL', 'Joplin, MO', 'Dover, DE',
#        'El Centro, CA', 'Jackson, TN', 'Yuba City, CA',
#        'Bowling Green, KY', 'St. George, UT', 'Muskegon, MI',
#        'Abilene, TX', 'Iowa City, IA', 'Auburn, AL', 'Midland, TX',
#        'Bloomington, IL', 'Hattiesburg, MS', 'Oshkosh, WI',
#        'Eau Claire, WI', 'Greenville, NC', 'Burlington, NC',
#        'Waterloo, IA', "Coeur d'Alene, ID", 'East Stroudsburg, PA',
#        'Pueblo, CO', 'Blacksburg, VA', 'Wausau, WI', 'Kahului, HI',
#        'Janesville, WI', 'Tupelo, MS', 'Bloomington, IN', 'Odessa, TX',
#        'Jackson, MI', 'State College, PA', 'Sebastian, FL', 'Madera, CA',
#        'Decatur, AL', 'Chambersburg, PA', 'Vineland, NJ',
#        'Idaho Falls, ID', 'Grand Junction, CO', 'Elizabethtown, KY',
#        'Niles, MI', 'Monroe, MI', 'Santa Fe, NM', 'Concord, NH',
#        'Alexandria, LA', 'Traverse City, MI', 'Bangor, ME',
#        'Homosassa Springs, FL', 'Hanford, CA', 'Jefferson City, MO',
#        'Florence, AL', 'Dothan, AL', 'London, KY', 'Albany, GA',
#        'Ottawa, IL', 'Sioux City, IA', 'Wichita Falls, TX',
#        'Texarkana, TX', 'Valdosta, GA', 'Logan, UT', 'Flagstaff, AZ',
#        'Rocky Mount, NC', 'Pottsville, PA', 'Dalton, GA', 'Lebanon, PA',
#        'Morristown, TN', 'Winchester, VA', 'Wheeling, WV',
#        'Morgantown, WV', 'La Crosse, WI', 'Napa, CA', 'Rapid City, SD',
#        'Sumter, SC', 'Eureka, CA', 'Springfield, OH', 'Harrisonburg, VA',
#        'Battle Creek, MI', 'Sherman, TX', 'Manhattan, KS',
#        'Carbondale, IL', 'Johnstown, PA', 'Jonesboro, AR', 'Bismarck, ND',
#        'Hammond, LA', 'Pittsfield, MA', 'Mount Vernon, WA',
#        'Jamestown, NY', 'The Villages, FL', 'Albany, OR',
#        'Glens Falls, NY', 'Lawton, OK', 'Cleveland, TN',
#        'Sierra Vista, AZ', 'Ames, IA', 'Mansfield, OH', 'Staunton, VA',
#        'Augusta, ME', 'Altoona, PA', 'New Bern, NC', 'Farmington, NM',
#        'St. Joseph, MO', 'San Angelo, TX', 'Wenatchee, WA',
#        'Owensboro, KY', 'Holland, MI', 'Lumberton, NC', 'Lawrence, KS',
#        'Goldsboro, NC', 'Watertown, NY', 'Sheboygan, WI', 'Weirton, WV',
#        'Missoula, MT', 'Wooster, OH', 'Bozeman, MT', 'Anniston, AL',
#        'Beckley, WV', 'Williamsport, PA', 'Brunswick, GA',
#        'California, MD', 'Twin Falls, ID', 'Cookeville, TN', 'Muncie, IN',
#        'Michigan City, IN', 'Roseburg, OR', 'Lewiston, ME',
#        'Longview, WA', 'Ogdensburg, NY', 'Kankakee, IL', 'Bluefield, WV',
#        'Show Low, AZ', 'Richmond, KY', 'Tullahoma, TN', 'Whitewater, WI',
#        'Ithaca, NY', 'Grand Forks, ND', 'Decatur, IL', 'LaGrange, GA',
#        'Bay City, MI', 'Fond du Lac, WI', 'Gettysburg, PA', 'Gadsden, AL',
#        'Kalispell, MT', 'Danville, VA', 'Mankato, MN', 'Lima, OH',
#        'Salem, OH', 'Truckee, CA', 'Sebring, FL', 'Cheyenne, WY',
#        'Hot Springs, AR', 'Adrian, MI', 'Shelby, NC', 'Dubuque, IA',
#        'Meridian, MS', 'Pinehurst, NC', 'Paducah, KY', 'Victoria, TX',
#        'Rome, GA', 'Sevierville, TN', 'Moses Lake, WA', 'Ashtabula, OH',
#        'Cape Girardeau, MO', 'Albertville, AL', 'Fairbanks, AK',
#        'Brainerd, MN', 'Cumberland, MD', 'Ocean City, NJ',
#        'Corvallis, OR', 'Pocatello, ID', 'Corning, NY',
#        'New Philadelphia, OH', 'Sunbury, PA', 'Ukiah, CA',
#        'Hermiston, OR', 'Clarksburg, WV', 'Parkersburg, WV',
#        'Beaver Dam, WI', 'Pine Bluff, AR', 'Grants Pass, OR',
#        'Cullman, AL', 'Lufkin, TX', 'Zanesville, OH', 'New Castle, PA',
#        'Oak Harbor, WA', 'Orangeburg, SC', 'Watertown, WI',
#        'Meadville, PA', 'Elmira, NY', 'Great Falls, MT', 'Laurel, MS',
#        'Russellville, AR', 'Indiana, PA', 'Midland, MI', 'Kokomo, IN',
#        'Bloomsburg, PA', 'Opelousas, LA', 'Helena, MT', 'Key West, FL',
#        'Talladega, AL', 'Stillwater, OK', 'Columbus, IN', 'Athens, TX',
#        'Centralia, WA', 'Manitowoc, WI', 'Hinesville, GA', 'DuBois, PA',
#        'Warsaw, IN', 'Plattsburgh, NY', 'Statesboro, GA', 'Casper, WY',
#        'Wilson, NC', 'Glenwood Springs, CO', 'Seneca, SC', 'Minot, ND',
#        'Olean, NY', 'Chillicothe, OH', 'Searcy, AR', 'Grand Island, NE',
#        'Port Angeles, WA', 'Auburn, NY', 'Huntsville, TX', 'Keene, NH',
#        'Heber, UT', 'Quincy, IL', 'Sandusky, OH', 'Findlay, OH',
#        'Frankfort, KY', 'Danville, IL', 'Aberdeen, WA', 'Portsmouth, OH',
#        'Somerset, PA', 'Wisconsin Rapids, WI', 'Jefferson, GA',
#        'Kapaa, HI', 'Palatka, FL', 'Gallup, NM', 'Hobbs, NM',
#        'Shawnee, OK', 'Fort Payne, AL', 'Mount Airy, NC',
#        'Stevens Point, WI', 'Greeneville, TN', 'Greenwood, SC',
#        'Lake City, FL', 'Klamath Falls, OR', 'Morehead City, NC',
#        'Clearlake, CA', 'Alamogordo, NM', 'Roanoke Rapids, NC',
#        'Farmington, MO', 'Muskogee, OK', 'Marion, IN', 'Faribault, MN',
#        'Richmond, IN', 'Marquette, MI', 'North Wilkesboro, NC',
#        'Mount Pleasant, MI', 'Rio Grande City, TX', 'Marion, OH',
#        'Baraboo, WI', 'Red Bluff, CA', 'Marinette, WI', 'Jasper, AL',
#        'Roswell, NM', 'Shelton, WA', 'Dublin, GA', 'Nacogdoches, TX',
#        'Somerset, KY', 'Coos Bay, OR', 'Forest City, NC',
#        'Martinsville, VA', 'Rexburg, ID', 'Lewiston, ID', 'Laconia, NH',
#        'Georgetown, SC', 'Athens, OH', 'Sanford, NC', 'Enid, OK',
#        'Mount Vernon, OH', 'Walla Walla, WA', 'Albemarle, NC',
#        'Hutchinson, KS', 'Hudson, NY', 'Starkville, MS', 'Carlsbad, NM',
#        'Gillette, WY', 'Sturgis, MI', 'Rutland, VT', 'Crossville, TN',
#        'Granbury, TX', 'Sayre, PA', 'Salina, KS', 'Marietta, OH',
#        'Fergus Falls, MN', 'Barre, VT', 'Fremont, OH', 'Oneonta, NY',
#        'Columbus, MS', 'Norwalk, OH', 'Batavia, NY', 'Ardmore, OK',
#        'Palestine, TX', 'Fort Madison, IA', 'Charleston, IL',
#        'Fernley, NV', 'Carson City, NV', 'Eagle Pass, TX', 'Calhoun, GA',
#        'Cullowhee, NC', 'Kearney, NE', 'Fairmont, WV', 'Ontario, OR',
#        'Gaffney, SC', 'Picayune, MS', 'Sterling, IL', 'Branson, MO',
#        'Cedar City, UT', 'Waycross, GA', 'Oxford, MS', 'Jasper, IN',
#        'Edwards, CO', 'Durango, CO', 'Kinston, NC', 'Sonora, CA',
#        'Tiffin, OH', 'Batesville, AR', 'Point Pleasant, WV', 'Elko, NV',
#        'Danville, KY', 'Glasgow, KY', 'St. Marys, GA', 'Boone, NC',
#        'Warrensburg, MO', 'Gloversville, NY', 'Fort Leonard Wood, MO',
#        'Poplar Bluff, MO', 'Elizabeth City, NC', 'Payson, AZ',
#        'Athens, TN', 'Enterprise, AL', 'Ashland, OH', 'Scottsboro, AL',
#        'Milledgeville, GA', 'Kerrville, TX', 'Bartlesville, OK',
#        'Platteville, WI', 'Corsicana, TX', 'Greenville, OH',
#        'Rochelle, IL', 'Alexander City, AL', 'Douglas, GA',
#        'Oil City, PA', 'Mason City, IA', 'Jacksonville, TX',
#        'Galesburg, IL', 'Pahrump, NV', 'Paris, TX', 'Winona, MN',
#        'Newport, OR', 'Morgan City, LA', 'Shelbyville, TN',
#        'Amsterdam, NY', 'Ozark, AL', 'Alice, TX',
#        'Gardnerville Ranchos, NV', 'Fort Polk South, LA',
#        'Ca-¦on City, CO', 'Natchez, MS', 'New Castle, IN', 'Clovis, NM',
#        'Norfolk, NE', 'Cadillac, MI', 'Ruston, LA', 'Sidney, OH',
#        'Pullman, WA', 'Malone, NY', 'Del Rio, TX', 'Blackfoot, ID',
#        'Red Wing, MN', 'Nogales, AZ', 'Tahlequah, OK', 'Kendallville, IN',
#        'Montrose, CO', 'Cortland, NY', 'Mount Sterling, KY',
#        'Clinton, IA', 'Sandpoint, ID', 'Bardstown, KY', 'Wapakoneta, OH',
#        'Plymouth, IN', 'Lewistown, PA', 'Bemidji, MN',
#        'Bellefontaine, OH', 'Seymour, IN', 'Burley, ID', 'Durant, OK',
#        'Moultrie, GA', 'Bogalusa, LA', 'Cornelia, GA', 'Hillsdale, MI',
#        'Thomasville, GA', 'Paragould, AR', 'Greenville, MS',
#        'Burlington, IA', 'Madisonville, KY', 'Menomonie, WI',
#        'Shawano, WI', 'Vicksburg, MS', 'Bedford, IN', 'Grand Rapids, MN',
#        'Washington, NC', 'Freeport, IL', 'Harrison, AR', 'Rolla, MO',
#        'Coldwater, MI', 'Marion, NC', 'Huntingdon, PA', 'Ellensburg, WA',
#        'Ponca City, OK', 'Lawrenceburg, TN', 'McAlester, OK',
#        'Mount Pleasant, TX', 'Willmar, MN', 'Rockingham, NC',
#        'Muscatine, IA', 'Lewisburg, PA', 'Auburn, IN', 'Duncan, OK',
#        'Sedalia, MO', 'Cedartown, GA', 'Henderson, NC', 'Aberdeen, SD',
#        'Rock Springs, WY', 'Garden City, KS', 'Stephenville, TX',
#        'Celina, OH', 'Wilmington, OH', 'Bucyrus, OH', 'Alma, MI',
#        'El Campo, TX', 'Mountain Home, AR', 'Gainesville, TX',
#        'Tifton, GA', 'Blytheville, AR', 'McMinnville, TN', 'Astoria, OR',
#        'Bradford, PA', 'Espa-¦ola, NM', 'McComb, MS', 'Big Stone Gap, VA',
#        'Marshalltown, IA', 'Big Rapids, MI', 'Austin, MN',
#        'Selinsgrove, PA', 'West Plains, MO', 'Okeechobee, FL',
#        'Houghton, MI', 'Moscow, ID', 'Clewiston, FL', 'Riverton, WY',
#        'El Dorado, AR', 'Selma, AL', 'Pittsburg, KS', 'Hannibal, MO',
#        'Warren, PA', 'Alexandria, MN', 'Urbana, OH', 'Greenwood, MS',
#        'Cambridge, OH', 'Williston, ND', 'Defiance, OH', 'Sikeston, MO',
#        'Safford, AZ', 'Jacksonville, IL', 'Ada, OK', 'Brownwood, TX',
#        'Crawfordsville, IN', 'Logansport, IN', 'Scottsbluff, NE',
#        'Natchitoches, LA', 'Newberry, SC', 'Lock Haven, PA',
#        'Centralia, IL', 'Easton, MD', 'Owatonna, MN', 'Mount Vernon, IL',
#        'Minden, LA', 'Laramie, WY', 'Murray, KY', 'Fremont, NE',
#        'Bennington, VT', 'Fort Dodge, IA', 'Sault Ste. Marie, MI',
#        'Campbellsville, KY', 'Dyersburg, TN', 'Atmore, AL',
#        'Escanaba, MI', 'Mayfield, KY', 'Kill Devil Hills, NC',
#        'Sulphur Springs, TX', 'Hutchinson, MN', 'Coshocton, OH',
#        'Huntington, IN', 'DeRidder, LA', 'Vincennes, IN', 'Bay City, TX',
#        'North Platte, NE', 'Peru, IN', 'Pontiac, IL', 'Lebanon, MO',
#        'Newport, TN', 'Decatur, IN', 'Vidalia, GA', 'Brenham, TX',
#        'Vernal, UT', 'Bonham, TX', 'Ottumwa, IA', 'Butte, MT',
#        'Corinth, MS', 'Brookhaven, MS', 'Emporia, KS', 'Jackson, WY',
#        'Winfield, KS', 'Big Spring, TX', 'Effingham, IL',
#        'Dodge City, KS', 'Watertown, SD', 'Angola, IN', 'Dixon, IL',
#        'Laurinburg, NC', 'Taos, NM', 'Brookings, SD', 'Americus, GA',
#        'Columbus, NE', 'Taylorville, IL', 'Arcadia, FL', 'Lewisburg, TN',
#        'Seneca Falls, NY', 'Dickinson, ND', 'Pella, IA', 'Washington, IN',
#        'Troy, AL', 'Malvern, AR', 'Frankfort, IN', 'Madison, IN',
#        'Brevard, NC', 'Susanville, CA', 'Martin, TN', 'Plainview, TX',
#        'Mount Gay, WV', 'Dayton, TN', 'Jackson, OH', 'Cambridge, MD',
#        'Paris, TN', 'Jennings, LA', 'Juneau, AK', 'Coffeyville, KS',
#        'Las Vegas, NM', 'Berlin, NH', 'Cleveland, MS', 'Hastings, NE',
#        'Beeville, TX', 'Kingsville, TX', 'Wabash, IN', 'Breckenridge, CO',
#        'St. Marys, PA', 'Central City, KY', 'Albert Lea, MN',
#        'Sheridan, WY', 'Union City, TN', 'Miami, OK', 'Iron Mountain, MI',
#        'Jesup, GA', 'McPherson, KS', 'Kirksville, MO', 'Ludington, MI',
#        'Bainbridge, GA', 'Alpena, MI', 'Washington Court House, OH',
#        'Hays, KS', 'Fort Morgan, CO', 'Van Wert, OH', 'Hope, AR',
#        'Kennett, MO', 'Weatherford, OK', 'Mountain Home, ID',
#        'Mineral Wells, TX', 'Lincoln, IL', 'Silver City, NM',
#        'Elkins, WV', 'Bluffton, IN', 'Macomb, IL', 'Camden, AR',
#        'Crescent City, CA', 'North Vernon, IN', 'Eufaula, AL',
#        'Thomaston, GA', 'Union, SC', 'Grants, NM', 'Bennettsville, SC',
#        'Fredericksburg, TX', 'Toccoa, GA', 'The Dalles, OR',
#        'Greensburg, IN', 'Indianola, MS', 'La Grande, OR', 'Ottawa, KS',
#        'New Ulm, MN', 'Lexington, NE', 'Great Bend, KS', 'Spearfish, SD',
#        'Wauchula, FL', 'Marshall, MN', 'Deming, NM', 'Mexico, MO',
#        'Fallon, NV', 'Altus, OK', 'Uvalde, TX', 'Hailey, ID',
#        'Steamboat Springs, CO', 'Summerville, GA', 'Moberly, MO',
#        'Middlesborough, KY', 'Woodward, OK', 'Prineville, OR',
#        'Scottsburg, IN', 'Rockport, TX', 'Hood River, OR',
#        'Forrest City, AR', 'Connersville, IN', 'Mitchell, SD',
#        'Marshall, MO', 'Brookings, OR', 'Yankton, SD', 'Wahpeton, ND',
#        'Magnolia, AR', 'Elk City, OK', 'Liberal, KS', 'Worthington, MN',
#        'Oskaloosa, IA', 'Pampa, TX', 'Clarksdale, MS', 'Sterling, CO',
#        'Beatrice, NE', 'Jamestown, ND', 'Levelland, TX', 'Grenada, MS',
#        'Maryville, MO', 'Arkadelphia, AR', 'Dumas, TX', 'Guymon, OK',
#        'Borger, TX', 'Pierre, SD', 'Huron, SD', 'Carroll, IA',
#        'Storm Lake, IA', 'Cordele, GA', 'Evanston, WY',
#        'Raymondville, TX', 'Port Lavaca, TX', 'Othello, WA',
#        'Vineyard Haven, MA', 'Parsons, KS', 'Price, UT', 'Ruidoso, NM',
#        'Fairmont, MN', 'Portales, NM', 'Los Alamos, NM', 'West Point, MS',
#        'Hereford, TX', 'Pearsall, TX', 'Andrews, TX', 'Brownsville, TN',
#        'Spirit Lake, IA', 'Fitzgerald, GA', 'Winnemucca, NV',
#        'Maysville, KY', 'Snyder, TX', 'Helena, AR', 'Spencer, IA',
#        'Atchison, KS', 'Fairfield, IA', 'Vermillion, SD',
#        'Sweetwater, TX', 'Pecos, TX', 'Zapata, TX', 'Ketchikan, AK',
#        'Craig, CO', 'Vernon, TX', 'Lamesa, TX'], dtype=object)

# %%
values_df = pd.read_csv('State_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
values_df.head(10)
# Zillow Home values index
# Out:
#    RegionID  SizeRank      RegionName RegionType  StateName     2000-01-31  \
# 0         9         0      California      state        NaN  184934.316357
# 1        54         1           Texas      state        NaN  108651.915493
# 2        14         2         Florida      state        NaN  105562.864543
# 3        43         3        New York      state        NaN  151332.776013
# 4        47         4    Pennsylvania      state        NaN   96293.945384
# 5        21         5        Illinois      state        NaN  123437.667880
# 6        44         6            Ohio      state        NaN  101966.849657
# 7        16         7         Georgia      state        NaN  120292.680630
# 8        36         8  North Carolina      state        NaN  124638.304235
# 9        30         9        Michigan      state        NaN  112096.013662
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0  185555.935794  186395.274250  188217.227773  190334.974283  ...
# 1  108710.959751  108739.597141  108881.727046  108973.772602  ...
# 2  105791.523534  106068.703810  106632.140020  107239.745255  ...
# 3  151871.669351  152390.441094  153506.178086  154660.567033  ...
# 4   96499.910841   96693.463044   97087.893024   97493.071373  ...
# 5  123536.591687  123750.419933  124253.448063  124850.306662  ...
# 6  102029.160651  102123.658578  102401.534292  102825.225655  ...
# 7  120565.844506  120881.029999  121544.633810  122276.562383  ...
# 8  124827.925303  125023.231196  125446.884175  125918.857135  ...
# 9  112157.753470  112383.787159  112834.045379  113498.044845  ...
#
#       2023-03-31     2023-04-30     2023-05-31     2023-06-30     2023-07-31  \
# 0  700645.417980  700071.790442  702993.413576  708109.782990  715006.691673
# 1  293015.813177  292651.823251  292966.319007  293782.318512  294517.200523
# 2  378905.178430  379344.093513  380382.617962  382034.246422  383713.911859
# 3  430860.488993  432344.784056  434774.062081  437629.211834  440656.724847
# 4  243504.365704  244306.951388  245814.703016  247602.348582  249341.677802
# 5  234771.175994  236088.328320  237907.502972  239989.378514  241936.049926
# 6  201471.383911  202777.618308  204653.286642  206755.228480  208665.747116
# 7  304249.627650  305150.191291  306620.745118  308270.832324  309927.318891
# 8  304191.612222  305201.971446  306781.321482  308652.981139  310411.400610
# 9  219221.630353  220335.319321  221952.491296  223600.483527  224882.071238
#
#       2023-08-31     2023-09-30     2023-10-31     2023-11-30     2023-12-31
# 0  722810.830530  730268.503111  736332.486797  740671.921245  743434.729197
# 1  295087.477528  295124.789296  294898.327140  294417.715350  293824.060476
# 2  385378.442796  386536.027985  387584.884146  388504.505535  389325.245410
# 3  443733.624198  446344.733234  448195.711473  449741.470945  451434.182956
# 4  251008.430940  252308.868444  253189.352626  253718.399927  254151.927536
# 5  243850.557222  245314.828108  246492.756924  247326.305012  247947.849104
# 6  210183.952192  211315.194492  212111.346698  212725.476823  213149.087494
# 7  311569.598620  313003.757875  314177.832709  315043.558679  315611.706086
# 8  312139.973983  313558.825231  314669.605925  315619.755461  316102.645449
# 9  226037.513807  226935.388182  227650.095417  228076.118487  228329.287519
#
# [10 rows x 293 columns]

# %%
values_df['RegionName'].unique()
# Out:
# array(['California', 'Texas', 'Florida', 'New York', 'Pennsylvania',
#        'Illinois', 'Ohio', 'Georgia', 'North Carolina', 'Michigan',
#        'New Jersey', 'Virginia', 'Washington', 'Arizona', 'Massachusetts',
#        'Tennessee', 'Indiana', 'Maryland', 'Missouri', 'Wisconsin',
#        'Colorado', 'Minnesota', 'South Carolina', 'Alabama', 'Louisiana',
#        'Kentucky', 'Oregon', 'Oklahoma', 'Connecticut', 'Utah', 'Iowa',
#        'Nevada', 'Arkansas', 'Mississippi', 'Kansas', 'New Mexico',
#        'Nebraska', 'Idaho', 'West Virginia', 'Hawaii', 'New Hampshire',
#        'Maine', 'Rhode Island', 'Montana', 'Delaware', 'South Dakota',
#        'North Dakota', 'Alaska', 'District of Columbia', 'Vermont',
#        'Wyoming'], dtype=object)

# %%
median_df = pd.read_csv('Metro_mlp_uc_sfr_sm_month.csv')
median_df.head(10)
# Median list price values per month
# Out:
#    RegionID  SizeRank        RegionName RegionType StateName  2018-03-31  \
# 0    102001         0     United States    country       NaN    262433.0
# 1    394913         1      New York, NY        msa        NY    492633.0
# 2    753899         2   Los Angeles, CA        msa        CA    778333.0
# 3    394463         3       Chicago, IL        msa        IL    295800.0
# 4    394514         4        Dallas, TX        msa        TX    325253.0
# 5    394692         5       Houston, TX        msa        TX    294633.0
# 6    395209         6    Washington, DC        msa        VA    421667.0
# 7    394974         7  Philadelphia, PA        msa        PA    226600.0
# 8    394856         8         Miami, FL        msa        FL    427500.0
# 9    394347         9       Atlanta, GA        msa        GA    288933.0
#
#    2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2023-03-31  \
# 0    270467.0    277133.0    280500.0    280800.0  ...    374000.0
# 1    499333.0    507966.0    516633.0    522967.0  ...    634633.0
# 2    791667.0    799667.0    806300.0    805967.0  ...    929966.0
# 3    309133.0    317600.0    321567.0    319933.0  ...    309967.0
# 4    330319.0    333613.0    333632.0    330298.0  ...    404630.0
# 5    298000.0    299666.0    299996.0    299663.0  ...    351300.0
# 6    438300.0    446633.0    454967.0    458333.0  ...    536667.0
# 7    235800.0    245800.0    254133.0    257967.0  ...    295000.0
# 8    431000.0    433333.0    435300.0    433300.0  ...    654667.0
# 9    298967.0    307996.0    311329.0    307963.0  ...    366667.0
#
#    2023-04-30  2023-05-31  2023-06-30  2023-07-31  2023-08-31  2023-09-30  \
# 0    381667.0    389667.0    396167.0    399167.0    397833.0    396333.0
# 1    644967.0    658300.0    666667.0    676600.0    676998.0    681938.0
# 2    961633.0    981333.0   1014667.0   1058000.0   1085000.0   1100000.0
# 3    320000.0    329967.0    337967.0    344300.0    344333.0    342666.0
# 4    416630.0    432667.0    444300.0    448967.0    446300.0    442833.0
# 5    357967.0    366332.0    372998.0    374998.0    373000.0    370317.0
# 6    556551.0    572884.0    581217.0    589333.0    586300.0    589300.0
# 7    303333.0    312625.0    320958.0    323958.0    322967.0    322967.0
# 8    674667.0    691333.0    699666.0    700000.0    700000.0    700000.0
# 9    376000.0    387333.0    395667.0    399633.0    399633.0    397967.0
#
#    2023-10-31  2023-11-30  2023-12-31
# 0    393300.0    389967.0    384633.0
# 1    684967.0    687902.0    687629.0
# 2   1075000.0   1065000.0   1033333.0
# 3    336333.0    332167.0    325833.0
# 4    437167.0    432167.0    427300.0
# 5    366982.0    363982.0    361082.0
# 6    589300.0    592667.0    579633.0
# 7    323300.0    323300.0    316633.0
# 8    700000.0    703333.0    710000.0
# 9    394633.0    389967.0    384933.0
#
# [10 rows x 75 columns]

# %%
median_df['RegionName'].unique()
# Out:
# array(['United States', 'New York, NY', 'Los Angeles, CA', 'Chicago, IL',
#        'Dallas, TX', 'Houston, TX', 'Washington, DC', 'Philadelphia, PA',
#        'Miami, FL', 'Atlanta, GA', 'Boston, MA', 'Phoenix, AZ',
#        'San Francisco, CA', 'Riverside, CA', 'Detroit, MI', 'Seattle, WA',
#        'Minneapolis, MN', 'San Diego, CA', 'Tampa, FL', 'Denver, CO',
#        'Baltimore, MD', 'St. Louis, MO', 'Orlando, FL', 'Charlotte, NC',
#        'San Antonio, TX', 'Portland, OR', 'Sacramento, CA',
#        'Pittsburgh, PA', 'Cincinnati, OH', 'Austin, TX', 'Las Vegas, NV',
#        'Kansas City, MO', 'Columbus, OH', 'Indianapolis, IN',
#        'Cleveland, OH', 'San Jose, CA', 'Nashville, TN',
#        'Virginia Beach, VA', 'Providence, RI', 'Jacksonville, FL',
#        'Milwaukee, WI', 'Oklahoma City, OK', 'Raleigh, NC', 'Memphis, TN',
#        'Richmond, VA', 'Louisville, KY', 'New Orleans, LA',
#        'Salt Lake City, UT', 'Hartford, CT', 'Buffalo, NY',
#        'Birmingham, AL', 'Rochester, NY', 'Grand Rapids, MI',
#        'Tucson, AZ', 'Urban Honolulu, HI', 'Tulsa, OK', 'Fresno, CA',
#        'Worcester, MA', 'Omaha, NE', 'Bridgeport, CT', 'Greenville, SC',
#        'Albuquerque, NM', 'Bakersfield, CA', 'Albany, NY',
#        'Knoxville, TN', 'Baton Rouge, LA', 'McAllen, TX', 'New Haven, CT',
#        'El Paso, TX', 'Allentown, PA', 'Oxnard, CA', 'Columbia, SC',
#        'North Port, FL', 'Dayton, OH', 'Charleston, SC', 'Greensboro, NC',
#        'Stockton, CA', 'Cape Coral, FL', 'Boise City, ID',
#        'Colorado Springs, CO', 'Little Rock, AR', 'Lakeland, FL',
#        'Akron, OH', 'Des Moines, IA', 'Springfield, MA',
#        'Poughkeepsie, NY', 'Ogden, UT', 'Madison, WI', 'Winston, NC',
#        'Deltona, FL', 'Syracuse, NY', 'Provo, UT', 'Toledo, OH',
#        'Wichita, KS', 'Durham, NC', 'Augusta, GA', 'Palm Bay, FL',
#        'Jackson, MS', 'Harrisburg, PA', 'Spokane, WA', 'Scranton, PA',
#        'Chattanooga, TN', 'Modesto, CA', 'Lancaster, PA', 'Portland, ME',
#        'Youngstown, OH', 'Lansing, MI', 'Fayetteville, AR',
#        'Fayetteville, NC', 'Lexington, KY', 'Pensacola, FL',
#        'Santa Rosa, CA', 'Reno, NV', 'Huntsville, AL',
#        'Port St. Lucie, FL', 'Lafayette, LA', 'Myrtle Beach, SC',
#        'Springfield, MO', 'Visalia, CA', 'Killeen, TX', 'Asheville, NC',
#        'York, PA', 'Vallejo, CA', 'Santa Maria, CA', 'Salinas, CA',
#        'Salem, OR', 'Mobile, AL', 'Reading, PA', 'Corpus Christi, TX',
#        'Brownsville, TX', 'Manchester, NH', 'Fort Wayne, IN',
#        'Gulfport, MS', 'Salisbury, MD', 'Flint, MI', 'Peoria, IL',
#        'Canton, OH', 'Savannah, GA', 'Anchorage, AK', 'Beaumont, TX',
#        'Shreveport, LA', 'Trenton, NJ', 'Montgomery, AL', 'Davenport, IA',
#        'Tallahassee, FL', 'Eugene, OR', 'Naples, FL', 'Ann Arbor, MI',
#        'Ocala, FL', 'Hickory, NC', 'Huntington, WV', 'Fort Collins, CO',
#        'Rockford, IL', 'Lincoln, NE', 'Gainesville, FL', 'Boulder, CO',
#        'Green Bay, WI', 'Columbus, GA', 'South Bend, IN',
#        'Spartanburg, SC', 'Greeley, CO', 'Lubbock, TX', 'Clarksville, TN',
#        'Roanoke, VA', 'Evansville, IN', 'Kingsport, TN', 'Kennewick, WA',
#        'Utica, NY', 'Hagerstown, MD', 'Duluth, MN', 'Olympia, WA',
#        'Longview, TX', 'Wilmington, NC', 'San Luis Obispo, CA',
#        'Crestview, FL', 'Merced, CA', 'Waco, TX', 'Cedar Rapids, IA',
#        'Atlantic City, NJ', 'Bremerton, WA', 'Sioux Falls, SD',
#        'Santa Cruz, CA', 'Erie, PA', 'Norwich, CT', 'Amarillo, TX',
#        'Laredo, TX', 'Tuscaloosa, AL', 'College Station, TX',
#        'Kalamazoo, MI', 'Lynchburg, VA', 'Charleston, WV', 'Yakima, WA',
#        'Fargo, ND', 'Binghamton, NY', 'Fort Smith, AR', 'Appleton, WI',
#        'Prescott Valley, AZ', 'Topeka, KS', 'Macon, GA', 'Tyler, TX',
#        'Barnstable Town, MA', 'Daphne, AL', 'Bellingham, WA',
#        'Burlington, VT', 'Rochester, MN', 'Lafayette, IN',
#        'Champaign, IL', 'Medford, OR', 'Lebanon, NH',
#        'Charlottesville, VA', 'Lake Charles, LA', 'Las Cruces, NM',
#        'Chico, CA', 'Hilton Head Island, SC', 'Athens, GA',
#        'Lake Havasu City, AZ', 'Columbia, MO', 'Springfield, IL',
#        'Houma, LA', 'Monroe, LA', 'Elkhart, IN', 'Johnson City, TN',
#        'Yuma, AZ', 'Gainesville, GA', 'Jacksonville, NC', 'Florence, SC',
#        'Hilo, HI', 'St. Cloud, MN', 'Racine, WI', 'Bend, OR',
#        'Saginaw, MI', 'Warner Robins, GA', 'Terre Haute, IN',
#        'Torrington, CT', 'Punta Gorda, FL', 'Billings, MT', 'Redding, CA',
#        'Kingston, NY', 'Panama City, FL', 'Joplin, MO', 'Dover, DE',
#        'El Centro, CA', 'Jackson, TN', 'Yuba City, CA',
#        'Bowling Green, KY', 'St. George, UT', 'Muskegon, MI',
#        'Abilene, TX', 'Iowa City, IA', 'Auburn, AL', 'Midland, TX',
#        'Bloomington, IL', 'Hattiesburg, MS', 'Oshkosh, WI',
#        'Eau Claire, WI', 'Greenville, NC', 'Burlington, NC',
#        'Waterloo, IA', "Coeur d'Alene, ID", 'East Stroudsburg, PA',
#        'Pueblo, CO', 'Blacksburg, VA', 'Wausau, WI', 'Kahului, HI',
#        'Janesville, WI', 'Tupelo, MS', 'Bloomington, IN', 'Odessa, TX',
#        'Jackson, MI', 'State College, PA', 'Sebastian, FL', 'Madera, CA',
#        'Decatur, AL', 'Chambersburg, PA', 'Vineland, NJ',
#        'Idaho Falls, ID', 'Grand Junction, CO', 'Elizabethtown, KY',
#        'Niles, MI', 'Monroe, MI', 'Santa Fe, NM', 'Concord, NH',
#        'Alexandria, LA', 'Traverse City, MI', 'Bangor, ME',
#        'Homosassa Springs, FL', 'Hanford, CA', 'Jefferson City, MO',
#        'Florence, AL', 'Dothan, AL', 'London, KY', 'Albany, GA',
#        'Ottawa, IL', 'Sioux City, IA', 'Wichita Falls, TX',
#        'Texarkana, TX', 'Valdosta, GA', 'Logan, UT', 'Flagstaff, AZ',
#        'Rocky Mount, NC', 'Pottsville, PA', 'Dalton, GA', 'Lebanon, PA',
#        'Morristown, TN', 'Winchester, VA', 'Wheeling, WV',
#        'Morgantown, WV', 'La Crosse, WI', 'Napa, CA', 'Rapid City, SD',
#        'Sumter, SC', 'Eureka, CA', 'Springfield, OH', 'Harrisonburg, VA',
#        'Battle Creek, MI', 'Sherman, TX', 'Manhattan, KS',
#        'Carbondale, IL', 'Johnstown, PA', 'Jonesboro, AR', 'Bismarck, ND',
#        'Hammond, LA', 'Pittsfield, MA', 'Mount Vernon, WA',
#        'Jamestown, NY', 'The Villages, FL', 'Albany, OR',
#        'Glens Falls, NY', 'Lawton, OK', 'Cleveland, TN',
#        'Sierra Vista, AZ', 'Ames, IA', 'Mansfield, OH', 'Staunton, VA',
#        'Augusta, ME', 'Altoona, PA', 'New Bern, NC', 'Farmington, NM',
#        'St. Joseph, MO', 'San Angelo, TX', 'Wenatchee, WA',
#        'Owensboro, KY', 'Holland, MI', 'Lumberton, NC', 'Lawrence, KS',
#        'Goldsboro, NC', 'Watertown, NY', 'Sheboygan, WI', 'Weirton, WV',
#        'Missoula, MT', 'Wooster, OH', 'Bozeman, MT', 'Anniston, AL',
#        'Beckley, WV', 'Williamsport, PA', 'Brunswick, GA',
#        'California, MD', 'Twin Falls, ID', 'Cookeville, TN', 'Muncie, IN',
#        'Michigan City, IN', 'Roseburg, OR', 'Lewiston, ME',
#        'Longview, WA', 'Ogdensburg, NY', 'Kankakee, IL', 'Bluefield, WV',
#        'Show Low, AZ', 'Richmond, KY', 'Tullahoma, TN', 'Whitewater, WI',
#        'Ithaca, NY', 'Grand Forks, ND', 'Decatur, IL', 'LaGrange, GA',
#        'Bay City, MI', 'Fond du Lac, WI', 'Gettysburg, PA', 'Gadsden, AL',
#        'Kalispell, MT', 'Danville, VA', 'Mankato, MN', 'Lima, OH',
#        'Salem, OH', 'Truckee, CA', 'Sebring, FL', 'Cheyenne, WY',
#        'Hot Springs, AR', 'Adrian, MI', 'Shelby, NC', 'Dubuque, IA',
#        'Meridian, MS', 'Pinehurst, NC', 'Paducah, KY', 'Victoria, TX',
#        'Rome, GA', 'Sevierville, TN', 'Moses Lake, WA', 'Ashtabula, OH',
#        'Cape Girardeau, MO', 'Albertville, AL', 'Fairbanks, AK',
#        'Brainerd, MN', 'Cumberland, MD', 'Ocean City, NJ',
#        'Corvallis, OR', 'Pocatello, ID', 'Corning, NY',
#        'New Philadelphia, OH', 'Sunbury, PA', 'Ukiah, CA',
#        'Hermiston, OR', 'Clarksburg, WV', 'Parkersburg, WV',
#        'Beaver Dam, WI', 'Pine Bluff, AR', 'Grants Pass, OR',
#        'Cullman, AL', 'Lufkin, TX', 'Zanesville, OH', 'New Castle, PA',
#        'Oak Harbor, WA', 'Orangeburg, SC', 'Watertown, WI',
#        'Meadville, PA', 'Elmira, NY', 'Great Falls, MT', 'Laurel, MS',
#        'Russellville, AR', 'Indiana, PA', 'Midland, MI', 'Kokomo, IN',
#        'Bloomsburg, PA', 'Opelousas, LA', 'Helena, MT', 'Key West, FL',
#        'Talladega, AL', 'Stillwater, OK', 'Columbus, IN', 'Athens, TX',
#        'Centralia, WA', 'Manitowoc, WI', 'Hinesville, GA', 'DuBois, PA',
#        'Warsaw, IN', 'Plattsburgh, NY', 'Statesboro, GA', 'Casper, WY',
#        'Wilson, NC', 'Glenwood Springs, CO', 'Seneca, SC', 'Minot, ND',
#        'Olean, NY', 'Chillicothe, OH', 'Searcy, AR', 'Grand Island, NE',
#        'Port Angeles, WA', 'Auburn, NY', 'Huntsville, TX', 'Keene, NH',
#        'Heber, UT', 'Quincy, IL', 'Sandusky, OH', 'Findlay, OH',
#        'Frankfort, KY', 'Danville, IL', 'Aberdeen, WA', 'Portsmouth, OH',
#        'Somerset, PA', 'Wisconsin Rapids, WI', 'Jefferson, GA',
#        'Kapaa, HI', 'Palatka, FL', 'Gallup, NM', 'Hobbs, NM',
#        'Shawnee, OK', 'Fort Payne, AL', 'Mount Airy, NC',
#        'Stevens Point, WI', 'Greeneville, TN', 'Greenwood, SC',
#        'Lake City, FL', 'Klamath Falls, OR', 'Morehead City, NC',
#        'Clearlake, CA', 'Alamogordo, NM', 'Roanoke Rapids, NC',
#        'Farmington, MO', 'Muskogee, OK', 'Marion, IN', 'Faribault, MN',
#        'Richmond, IN', 'Marquette, MI', 'North Wilkesboro, NC',
#        'Mount Pleasant, MI', 'Rio Grande City, TX', 'Marion, OH',
#        'Baraboo, WI', 'Red Bluff, CA', 'Marinette, WI', 'Jasper, AL',
#        'Roswell, NM', 'Shelton, WA', 'Dublin, GA', 'Nacogdoches, TX',
#        'Somerset, KY', 'Coos Bay, OR', 'Forest City, NC',
#        'Martinsville, VA', 'Rexburg, ID', 'Lewiston, ID', 'Laconia, NH',
#        'Georgetown, SC', 'Athens, OH', 'Sanford, NC', 'Enid, OK',
#        'Mount Vernon, OH', 'Walla Walla, WA', 'Albemarle, NC',
#        'Hutchinson, KS', 'Hudson, NY', 'Starkville, MS', 'Carlsbad, NM',
#        'Gillette, WY', 'Sturgis, MI', 'Rutland, VT', 'Crossville, TN',
#        'Granbury, TX', 'Sayre, PA', 'Salina, KS', 'Marietta, OH',
#        'Fergus Falls, MN', 'Barre, VT', 'Fremont, OH', 'Oneonta, NY',
#        'Columbus, MS', 'Norwalk, OH', 'Batavia, NY', 'Ardmore, OK',
#        'Palestine, TX', 'Fort Madison, IA', 'Charleston, IL',
#        'Fernley, NV', 'Carson City, NV', 'Eagle Pass, TX', 'Calhoun, GA',
#        'Cullowhee, NC', 'Kearney, NE', 'Fairmont, WV', 'Ontario, OR',
#        'Gaffney, SC', 'Picayune, MS', 'Sterling, IL', 'Branson, MO',
#        'Cedar City, UT', 'Waycross, GA', 'Oxford, MS', 'Jasper, IN',
#        'Edwards, CO', 'Durango, CO', 'Kinston, NC', 'Sonora, CA',
#        'Tiffin, OH', 'Batesville, AR', 'Point Pleasant, WV', 'Elko, NV',
#        'Danville, KY', 'Glasgow, KY', 'St. Marys, GA', 'Boone, NC',
#        'Warrensburg, MO', 'Gloversville, NY', 'Fort Leonard Wood, MO',
#        'Poplar Bluff, MO', 'Elizabeth City, NC', 'Payson, AZ',
#        'Athens, TN', 'Enterprise, AL', 'Ashland, OH', 'Scottsboro, AL',
#        'Milledgeville, GA', 'Kerrville, TX', 'Bartlesville, OK',
#        'Platteville, WI', 'Corsicana, TX', 'Greenville, OH',
#        'Rochelle, IL', 'Alexander City, AL', 'Douglas, GA',
#        'Oil City, PA', 'Mason City, IA', 'Jacksonville, TX',
#        'Galesburg, IL', 'Pahrump, NV', 'Paris, TX', 'Winona, MN',
#        'Newport, OR', 'Morgan City, LA', 'Shelbyville, TN',
#        'Amsterdam, NY', 'Ozark, AL', 'Alice, TX',
#        'Gardnerville Ranchos, NV', 'Fort Polk South, LA',
#        'Ca-¦on City, CO', 'Natchez, MS', 'New Castle, IN', 'Clovis, NM',
#        'Norfolk, NE', 'Cadillac, MI', 'Ruston, LA', 'Sidney, OH',
#        'Pullman, WA', 'Malone, NY', 'Del Rio, TX', 'Blackfoot, ID',
#        'Red Wing, MN', 'Nogales, AZ', 'Tahlequah, OK', 'Kendallville, IN',
#        'Montrose, CO', 'Cortland, NY', 'Mount Sterling, KY',
#        'Clinton, IA', 'Sandpoint, ID', 'Bardstown, KY', 'Wapakoneta, OH',
#        'Plymouth, IN', 'Lewistown, PA', 'Bemidji, MN',
#        'Bellefontaine, OH', 'Seymour, IN', 'Burley, ID', 'Durant, OK',
#        'Moultrie, GA', 'Bogalusa, LA', 'Cornelia, GA', 'Hillsdale, MI',
#        'Thomasville, GA', 'Paragould, AR', 'Greenville, MS',
#        'Burlington, IA', 'Madisonville, KY', 'Menomonie, WI',
#        'Shawano, WI', 'Vicksburg, MS', 'Bedford, IN', 'Grand Rapids, MN',
#        'Washington, NC', 'Freeport, IL', 'Harrison, AR', 'Rolla, MO',
#        'Coldwater, MI', 'Marion, NC', 'Huntingdon, PA', 'Ellensburg, WA',
#        'Ponca City, OK', 'Lawrenceburg, TN', 'McAlester, OK',
#        'Mount Pleasant, TX', 'Willmar, MN', 'Rockingham, NC',
#        'Muscatine, IA', 'Lewisburg, PA', 'Auburn, IN', 'Duncan, OK',
#        'Sedalia, MO', 'Cedartown, GA', 'Henderson, NC', 'Aberdeen, SD',
#        'Rock Springs, WY', 'Garden City, KS', 'Stephenville, TX',
#        'Celina, OH', 'Wilmington, OH', 'Bucyrus, OH', 'Alma, MI',
#        'El Campo, TX', 'Mountain Home, AR', 'Gainesville, TX',
#        'Tifton, GA', 'Blytheville, AR', 'McMinnville, TN', 'Astoria, OR',
#        'Bradford, PA', 'Espa-¦ola, NM', 'McComb, MS', 'Big Stone Gap, VA',
#        'Marshalltown, IA', 'Big Rapids, MI', 'Austin, MN',
#        'Selinsgrove, PA', 'West Plains, MO', 'Okeechobee, FL',
#        'Houghton, MI', 'Moscow, ID', 'Clewiston, FL', 'Riverton, WY',
#        'El Dorado, AR', 'Selma, AL', 'Pittsburg, KS', 'Hannibal, MO',
#        'Warren, PA', 'Alexandria, MN', 'Urbana, OH', 'Greenwood, MS',
#        'Cambridge, OH', 'Williston, ND', 'Defiance, OH', 'Sikeston, MO',
#        'Safford, AZ', 'Jacksonville, IL', 'Ada, OK', 'Brownwood, TX',
#        'Crawfordsville, IN', 'Logansport, IN', 'Scottsbluff, NE',
#        'Natchitoches, LA', 'Newberry, SC', 'Lock Haven, PA',
#        'Centralia, IL', 'Easton, MD', 'Owatonna, MN', 'Mount Vernon, IL',
#        'Minden, LA', 'Laramie, WY', 'Murray, KY', 'Fremont, NE',
#        'Bennington, VT', 'Fort Dodge, IA', 'Sault Ste. Marie, MI',
#        'Campbellsville, KY', 'Dyersburg, TN', 'Atmore, AL',
#        'Escanaba, MI', 'Mayfield, KY', 'Kill Devil Hills, NC',
#        'Sulphur Springs, TX', 'Hutchinson, MN', 'Coshocton, OH',
#        'Huntington, IN', 'DeRidder, LA', 'Vincennes, IN', 'Bay City, TX',
#        'North Platte, NE', 'Peru, IN', 'Pontiac, IL', 'Lebanon, MO',
#        'Newport, TN', 'Decatur, IN', 'Vidalia, GA', 'Brenham, TX',
#        'Vernal, UT', 'Bonham, TX', 'Ottumwa, IA', 'Butte, MT',
#        'Corinth, MS', 'Brookhaven, MS', 'Emporia, KS', 'Jackson, WY',
#        'Winfield, KS', 'Big Spring, TX', 'Effingham, IL',
#        'Dodge City, KS', 'Watertown, SD', 'Angola, IN', 'Dixon, IL',
#        'Laurinburg, NC', 'Taos, NM', 'Brookings, SD', 'Americus, GA',
#        'Columbus, NE', 'Taylorville, IL', 'Arcadia, FL', 'Lewisburg, TN',
#        'Seneca Falls, NY', 'Dickinson, ND', 'Pella, IA', 'Washington, IN',
#        'Troy, AL', 'Malvern, AR', 'Frankfort, IN', 'Madison, IN',
#        'Brevard, NC', 'Susanville, CA', 'Martin, TN', 'Plainview, TX',
#        'Mount Gay, WV', 'Dayton, TN', 'Jackson, OH', 'Cambridge, MD',
#        'Paris, TN', 'Jennings, LA', 'Juneau, AK', 'Coffeyville, KS',
#        'Las Vegas, NM', 'Berlin, NH', 'Cleveland, MS', 'Hastings, NE',
#        'Beeville, TX', 'Kingsville, TX', 'Wabash, IN', 'Breckenridge, CO',
#        'St. Marys, PA', 'Central City, KY', 'Albert Lea, MN',
#        'Sheridan, WY', 'Union City, TN', 'Miami, OK', 'Iron Mountain, MI',
#        'Jesup, GA', 'McPherson, KS', 'Kirksville, MO', 'Ludington, MI',
#        'Bainbridge, GA', 'Alpena, MI', 'Washington Court House, OH',
#        'Hays, KS', 'Fort Morgan, CO', 'Van Wert, OH', 'Hope, AR',
#        'Kennett, MO', 'Weatherford, OK', 'Mountain Home, ID',
#        'Mineral Wells, TX', 'Lincoln, IL', 'Silver City, NM',
#        'Elkins, WV', 'Bluffton, IN', 'Macomb, IL', 'Camden, AR',
#        'Crescent City, CA', 'North Vernon, IN', 'Eufaula, AL',
#        'Thomaston, GA', 'Union, SC', 'Grants, NM', 'Fredericksburg, TX',
#        'Toccoa, GA', 'The Dalles, OR', 'Greensburg, IN', 'Indianola, MS',
#        'La Grande, OR', 'Ottawa, KS', 'New Ulm, MN', 'Lexington, NE',
#        'Great Bend, KS', 'Spearfish, SD', 'Wauchula, FL', 'Marshall, MN',
#        'Deming, NM', 'Mexico, MO', 'Fallon, NV', 'Altus, OK',
#        'Uvalde, TX', 'Hailey, ID', 'Steamboat Springs, CO',
#        'Summerville, GA', 'Moberly, MO', 'Middlesborough, KY',
#        'Woodward, OK', 'Prineville, OR', 'Scottsburg, IN', 'Rockport, TX',
#        'Hood River, OR', 'Forrest City, AR', 'Connersville, IN',
#        'Mitchell, SD', 'Marshall, MO', 'Brookings, OR', 'Yankton, SD',
#        'Wahpeton, ND', 'Magnolia, AR', 'Elk City, OK', 'Liberal, KS',
#        'Worthington, MN', 'Oskaloosa, IA', 'Pampa, TX', 'Clarksdale, MS',
#        'Sterling, CO', 'Beatrice, NE', 'Jamestown, ND', 'Levelland, TX',
#        'Grenada, MS', 'Maryville, MO', 'Arkadelphia, AR', 'Dumas, TX',
#        'Guymon, OK', 'Borger, TX', 'Pierre, SD', 'Huron, SD',
#        'Carroll, IA', 'Storm Lake, IA', 'Cordele, GA', 'Evanston, WY',
#        'Raymondville, TX', 'Port Lavaca, TX', 'Othello, WA',
#        'Vineyard Haven, MA', 'Parsons, KS', 'Price, UT', 'Ruidoso, NM',
#        'Fairmont, MN', 'Portales, NM', 'Los Alamos, NM', 'West Point, MS',
#        'Hereford, TX', 'Pearsall, TX', 'Andrews, TX', 'Brownsville, TN',
#        'Spirit Lake, IA', 'Fitzgerald, GA', 'Winnemucca, NV',
#        'Maysville, KY', 'Snyder, TX', 'Helena, AR', 'Spencer, IA',
#        'Atchison, KS', 'Fairfield, IA', 'Vermillion, SD',
#        'Sweetwater, TX', 'Pecos, TX', 'Zapata, TX', 'Ketchikan, AK',
#        'Craig, CO', 'Vernon, TX', 'Lamesa, TX'], dtype=object)

# %%
df.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 75 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RegionID    928 non-null    int64
#  1   SizeRank    928 non-null    int64
#  2   RegionName  928 non-null    object
#  3   RegionType  928 non-null    object
#  4   StateName   927 non-null    object
#  5   2018-03-31  899 non-null    float64
#  6   2018-04-30  899 non-null    float64
#  7   2018-05-31  899 non-null    float64
#  8   2018-06-30  900 non-null    float64
#  9   2018-07-31  900 non-null    float64
#  10  2018-08-31  900 non-null    float64
#  11  2018-09-30  900 non-null    float64
#  12  2018-10-31  900 non-null    float64
#  13  2018-11-30  900 non-null    float64
#  14  2018-12-31  900 non-null    float64
#  15  2019-01-31  900 non-null    float64
#  16  2019-02-28  900 non-null    float64
#  17  2019-03-31  900 non-null    float64
#  18  2019-04-30  900 non-null    float64
#  19  2019-05-31  900 non-null    float64
#  20  2019-06-30  900 non-null    float64
#  21  2019-07-31  900 non-null    float64
#  22  2019-08-31  900 non-null    float64
#  23  2019-09-30  900 non-null    float64
#  24  2019-10-31  900 non-null    float64
#  25  2019-11-30  900 non-null    float64
#  26  2019-12-31  900 non-null    float64
#  27  2020-01-31  900 non-null    float64
#  28  2020-02-29  900 non-null    float64
#  29  2020-03-31  900 non-null    float64
#  30  2020-04-30  900 non-null    float64
#  31  2020-05-31  900 non-null    float64
#  32  2020-06-30  897 non-null    float64
#  33  2020-07-31  899 non-null    float64
#  34  2020-08-31  899 non-null    float64
#  35  2020-09-30  899 non-null    float64
#  36  2020-10-31  899 non-null    float64
#  37  2020-11-30  898 non-null    float64
#  38  2020-12-31  898 non-null    float64
#  39  2021-01-31  889 non-null    float64
#  40  2021-02-28  899 non-null    float64
#  41  2021-03-31  918 non-null    float64
#  42  2021-04-30  922 non-null    float64
#  43  2021-05-31  918 non-null    float64
#  44  2021-06-30  917 non-null    float64
#  45  2021-07-31  914 non-null    float64
#  46  2021-08-31  911 non-null    float64
#  47  2021-09-30  919 non-null    float64
#  48  2021-10-31  920 non-null    float64
#  49  2021-11-30  920 non-null    float64
#  50  2021-12-31  921 non-null    float64
#  51  2022-01-31  923 non-null    float64
#  52  2022-02-28  923 non-null    float64
#  53  2022-03-31  923 non-null    float64
#  54  2022-04-30  923 non-null    float64
#  55  2022-05-31  923 non-null    float64
#  56  2022-06-30  923 non-null    float64
#  57  2022-07-31  923 non-null    float64
#  58  2022-08-31  923 non-null    float64
#  59  2022-09-30  923 non-null    float64
#  60  2022-10-31  925 non-null    float64
#  61  2022-11-30  925 non-null    float64
#  62  2022-12-31  925 non-null    float64
#  63  2023-01-31  928 non-null    float64
#  64  2023-02-28  928 non-null    float64
#  65  2023-03-31  928 non-null    float64
#  66  2023-04-30  928 non-null    float64
#  67  2023-05-31  928 non-null    float64
#  68  2023-06-30  926 non-null    float64
#  69  2023-07-31  927 non-null    float64
#  70  2023-08-31  927 non-null    float64
#  71  2023-09-30  928 non-null    float64
#  72  2023-10-31  928 non-null    float64
#  73  2023-11-30  928 non-null    float64
#  74  2023-12-31  928 non-null    float64
# dtypes: float64(70), int64(2), object(3)
# memory usage: 543.9+ KB

# %%
prices = df['PRICE']
plt.plot(prices, kind='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/joules/Desktop/test/PROJECT 3/test.ipynb Cell 6 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/joules/Desktop/test/PROJECT%203/test.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> prices = df['PRICE']
#       <a href='vscode-notebook-cell:/Users/joules/Desktop/test/PROJECT%203/test.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> plt.plot(prices, kind='bar')
# ----> <a href='vscode-notebook-cell:/Users/joules/Desktop/test/PROJECT%203/test.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> plt.show
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/_plotly_utils/importers.py:39, in relative_import.<locals>.__getattr__(import_name)
#      36     class_module = importlib.import_module(rel_module, parent_name)
#      37     return getattr(class_module, class_name)
# ---> 39 raise AttributeError(
#      40     "module {__name__!r} has no attribute {name!r}".format(
#      41         name=import_name, __name__=parent_name
#      42     )
#      43 )
#
# AttributeError: module 'plotly' has no attribute 'show'

# %%
df['TYPE'].value_counts()
# Out:
# Co-op for sale                1450
# House for sale                1012
# Condo for sale                 891
# Multi-family home for sale     727
# Townhouse for sale             299
# Pending                        243
# Contingent                      88
# Land for sale                   49
# For sale                        20
# Foreclosure                     14
# Condop for sale                  5
# Coming Soon                      2
# Mobile house for sale            1
# Name: TYPE, dtype: int64

# %%
longitudes = df['LONGITUDE']
latitudes = df['LATITUDE']
colors = latitudes
fig = go.Figure(go.Scattermapbox(
    mode="markers",
    lon=longitudes,
    lat=latitudes,
    marker=dict(
        size=10,
        color=colors,
        colorscale="Viridis",  # Choose a colorscale
        cmin=min(colors),
        cmax=max(colors),
        colorbar=dict(title="Types for Sale")),
))

# Update layout to use a mapbox
fig.update_layout(
    mapbox_style="carto-positron",
    mapbox=dict(center=dict(lon=np.mean(longitudes), lat=np.mean(latitudes)), zoom=3),
)
